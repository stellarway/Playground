# %% [markdown]
# # REST API

# %%
import requests
from bs4 import BeautifulSoup
import urllib

# %%
BASE_ENDPOINT='http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/'
#붙여 넣고 뒤에 슬래쉬 붙이기!!!
MY_API_KEY='yeq8B1zUUCHXkJw8ebFFe9%2FZ8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ%3D%3D'
MY_API_KEY=urllib.parse.unquote(MY_API_KEY)
#이 과정을 통해 다시 디코딩 해줘야한다.
MY_API_KEY
# Out:
# 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ=='

# %%
OPERATION_NAME='getMsrstnAcctoRltmMesureDnsty'

# %%
endpoint=urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
endpoint
# Out:
# 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'

# %%
params={
    'ServiceKey': MY_API_KEY,
    'numOfRows': 10,
    'pageNo':1,
    'stationName':'강남구',
    'dataTerm':'DAILY',
    'ver':'1.3'
}

# %%
resp=requests.get(endpoint,params)

# %%
resp.content
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>00</resultCode>\r\n\t\t<resultMsg>NORMAL SERVICE.</resultMsg>\r\n\t</header>\r\n\t<body>\r\n\t\t<items>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2019-06-10 10:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.004</so2Value>\r\n\t\t\t\t\t<coValue>0.3</coValue>\r\n\t\t\t\t\t<o3Value>0.015</o3Value>\r\n\t\t\t\t\t<no2Value>0.016</no2Value>\r\n\t\t\t\t\t<pm10Value>7</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>8</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>3</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>4</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>27</khaiValue>\r\n\t\t\t\t\t<khaiGrade>1</khaiGrade>\r\n\t\t\t\t\t<so2Grade>1</so2Grade>\r\n\t\t\t\t\t<coGrade>1</coGrade>\r\n\t\t\t\t\t<o3Grade>1</o3Grade>\r\n\t\t\t\t\t<no2Grade>1</no2Grade>\r\n\t\t\t\t\t<pm10Grade>1</pm10Grade>\r\n\t\t\t\t\t\r\n                        <pm25Grade>1</pm25Grade>\r\n                    \r\n                    \r\n                        <pm10Grade1h>1</pm10Grade1h>\r\n                        <pm25Grade1h>1</pm25Grade1h>\r\n                    \r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2019-06-10 09:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.004</so2Value>\r\n\t\t\t\t\t<coValue>0.3</coValue>\r\n\t\t\t\t\t<o3Value>0.010</o3Value>\r\n\t\t\t\t\t<no2Value>0.019</no2Value>\r\n\t\t\t\t\t<pm10Value>9</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>9</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>4</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>5</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>32</khaiValue>\r\n\t\t\t\t\t<khaiGrade>1</khaiGrade>\r\n\t\t\t\t\t<so2Grade>1</so2Grade>\r\n\t\t\t\t\t<coGrade>1</coGrade>\r\n\t\t\t\t\t<o3Grade>1</o3Grade>\r\n\t\t\t\t\t<no2Grade>1</no2Grade>\r\n\t\t\t\t\t<pm10Grade>1</pm10Grade>\r\n\t\t\t\t\t\r\n                        <pm25Grade>1</pm25Grade>\r\n                    \r\n                    \r\n                        <pm10Grade1h>1</pm10Grade1h>\r\n                        <pm25Grade1h>1</pm25Grade1h>\r\n                    \r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2019-06-10 08:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.003</so2Value>\r\n\t\t\t\t\t<coValue>0.3</coValue>\r\n\t\t\t\t\t<o3Value>0.012</o3Value>\r\n\t\t\t\t\t<no2Value>0.020</no2Value>\r\n\t\t\t\t\t<pm10Value>7</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>9</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>3</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>5</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>33</khaiValue>\r\n\t\t\t\t\t<khaiGrade>1</khaiGrade>\r\n\t\t\t\t\t<so2Grade>1</so2Grade>\r\n\t\t\t\t\t<coGrade>1</coGrade>\r\n\t\t\t\t\t<o3Grade>1</o3Grade>\r\n\t\t\t\t\t<no2Grade>1</no2Grade>\r\n\t\t\t\t\t<pm10Grade>1</pm10Grade>\r\n\t\t\t\t\t\r\n                        <pm25Grade>1</pm25Grade>\r\n                    \r\n                    \r\n                        <pm10Grade1h>1</pm10Grade1h>\r\n                        <pm25Grade1h>1</pm25Grade1h>\r\n                    \r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2019-06-10 07:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f ...

# %%
resp.request.url
#공공데이터 인증키가 원래 UTF-8로 인코딩 되어 있다.
# Out:
# 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?ServiceKey=yeq8B1zUUCHXkJw8ebFFe9%2FZ8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ%3D%3D&numOfRows=10&pageNo=1&stationName=%EA%B0%95%EB%82%A8%EA%B5%AC&dataTerm=DAILY&ver=1.3'

# %%
soup=BeautifulSoup(resp.content)

# %%
soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><response>
# <header>
# <resultcode>00</resultcode>
# <resultmsg>NORMAL SERVICE.</resultmsg>
# </header>
# <items>
# <item>
# <datatime>2019-06-10 10:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.004</so2value>
# <covalue>0.3</covalue>
# <o3value>0.015</o3value>
# <no2value>0.016</no2value>
# <pm10value>7</pm10value>
# <pm10value24>8</pm10value24>
# <pm25value>3</pm25value>
# <pm25value24>4</pm25value24>
# <khaivalue>27</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 09:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.004</so2value>
# <covalue>0.3</covalue>
# <o3value>0.010</o3value>
# <no2value>0.019</no2value>
# <pm10value>9</pm10value>
# <pm10value24>9</pm10value24>
# <pm25value>4</pm25value>
# <pm25value24>5</pm25value24>
# <khaivalue>32</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 08:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.003</so2value>
# <covalue>0.3</covalue>
# <o3value>0.012</o3value>
# <no2value>0.020</no2value>
# <pm10value>7</pm10value>
# <pm10value24>9</pm10value24>
# <pm25value>3</pm25value>
# <pm25value24>5</pm25value24>
# <khaivalue>33</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 07:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.005</so2value>
# <covalue>0.2</covalue>
# <o3value>0.012</o3value>
# <no2value>0.017</no2value>
# <pm10value>9</pm10value>
# <pm10value24>10</pm10value24>
# <pm25value>5</pm25value>
# <pm25value24>6</pm25value24>
# <khaivalue>28</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 06:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.004</so2value>
# <covalue>0.2</covalue>
# <o3value>0.021</o3value>
# <no2value>0.009</no2value>
# <pm10value>7</pm10value>
# <pm10value24>10</pm10value24>
# <pm25value>4</pm25value>
# <pm25value24>7</pm25value24>
# <khaivalue>35</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 05:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.005</so2value>
# <covalue>0.2</covalue>
# <o3value>0.025</o3value>
# <no2value>0.007</no2value>
# <pm10value>9</pm10value>
# <pm10value24>12</pm10value24>
# <pm25value>4</pm25value>
# <pm25value24>8</pm25value24>
# <khaivalue>42</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 04:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.004</so2value>
# <covalue>0.2</covalue>
# <o3value>0.022</o3value>
# <no2value>0.006</no2value>
# <pm10value>7</pm10value>
# <pm10value24>13</pm10value24>
# <pm25value>5</pm25value>
# <pm25value24>9</pm25value24>
# <khaivalue>37</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 03:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.004</so2value>
# <covalue>0.2</covalue>
# <o3value>0.027</o3value>
# <no2value>0.006</no2value>
# <pm10value>9</pm10value>
# <pm10value24>15</pm10value24>
# <pm25value>6</pm25value>
# <pm25value24>10</pm25value24>
# <khaivalue>45</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 02:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.005</so2value>
# <covalue>0.2</covalue>
# <o3value>0.031</o3value>
# <no2value>0.007</no2value>
# <pm10value>10</pm10value>
# <pm10value24>16</pm10value24>
# <pm25value>6</pm25value>
# <pm25value24>11</pm25value24>
# <khaivalue>51</khaivalue>
# <khaigrade>2</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>2</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 01:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.004</so2value>
# <covalue>0.2</covalue>
# <o3value>0.027</o3value>
# <no2value>0.007</no2value>
# <pm10value>13</pm10value>
# <pm10value24>18</pm10value24>
# <pm25value>7</pm25value>
# <pm25value24>12</pm25value24>
# <khaivalue>45</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h>1</pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# </items>
# <numofrows>10</numofrows>
# <pageno>1</pageno>
# <totalcount>23</totalcount>
# </response>
# </body></html>

# %%
params={
    'ServiceKey': MY_API_KEY,
    'numOfRows': 10,
    'pageNo':1,
    'stationName':'강남구',
    'dataTerm':'DAILY',
    'ver':'1.3',
    '_returnType': 'json'
}

# %%
resp=requests.get(endpoint, params)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'{"list":[{"_returnType":"json","coGrade":"1","coValue":"0.3","dataTerm":"","dataTime":"2019-06-10 10:00","khaiGrade":"1","khaiValue":"27","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.016","numOfRows":"10","o3Grade":"1","o3Value":"0.015","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"7","pm10Value24":"8","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"3","pm25Value24":"4","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sidoName":"","so2Grade":"1","so2Value":"0.004","stationCode":"","stationName":"","totalCount":"","ver":""},{"_returnType":"json","coGrade":"1","coValue":"0.3","dataTerm":"","dataTime":"2019-06-10 09:00","khaiGrade":"1","khaiValue":"32","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.019","numOfRows":"10","o3Grade":"1","o3Value":"0.010","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"9","pm10Value24":"9","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"4","pm25Value24":"5","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sidoName":"","so2Grade":"1","so2Value":"0.004","stationCode":"","stationName":"","totalCount":"","ver":""},{"_returnType":"json","coGrade":"1","coValue":"0.3","dataTerm":"","dataTime":"2019-06-10 08:00","khaiGrade":"1","khaiValue":"33","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.020","numOfRows":"10","o3Grade":"1","o3Value":"0.012","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"7","pm10Value24":"9","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"3","pm25Value24":"5","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sidoName":"","so2Grade":"1","so2Value":"0.003","stationCode":"","stationName":"","totalCount":"","ver":""},{"_returnType":"json","coGrade":"1","coValue":"0.2","dataTerm":"","dataTime":"2019-06-10 07:00","khaiGrade":"1","khaiValue":"28","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.017","numOfRows":"10","o3Grade":"1","o3Value":"0.012","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"9","pm10Value24":"10","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"5","pm25Value24":"6","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sidoName":"","so2Grade":"1","so2Value":"0.005","stationCode":"","stationName":"","totalCount":"","ver":""},{"_returnType":"json","coGrade":"1","coValue":"0.2","dataTerm":"","dataTime":"2019-06-10 06:00","khaiGrade":"1","khaiValue":"35","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.009","numOfRows":"10","o3Grade":"1","o3Value":"0.021","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"7","pm10Value24":"10","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"4","pm25Value24":"7","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sidoName":"","so2Grade":"1","so2Value":"0.004","stationCode":"","stationName":"","totalCount":"","ver":""},{"_returnType":"json","coGrade":"1","coValue":"0.2","dataTerm":"","dataTime":"2019-06-10 05:00","khaiGrade":"1","khaiValue":"42","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.007","numOfRows":"10","o3Grade":"1","o3Value":"0.025","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"9","pm10Value24":"12","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"4","pm25Value24":"8","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sidoName":"","so2Grade":"1","so2Value":"0.005","stationCode":"","stationName":"","totalCount":"","ver":""},{"_returnType":"json","coGrade":"1","coValue":"0.2","dataTerm":"","dataTime":"2019-06-10 04:00","khaiGrade":"1","khaiValue":"37","mangName":"\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0","no2Grade":"1","no2Value":"0.006","numOfRows":"10","o3Grade":"1","o3Value":"0.022","pageNo":"1","pm10Grade":"1","pm10Grade1h":"1","pm10Value":"7","pm10Value24":"13","pm25Grade":"1","pm25Grade1h":"1","pm25Value":"5","pm25Value24":"9","resultCode":"","resultMsg":"","rnum":0, ...

# %%
resp.json()
# Out:
# {'list': [{'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 10:00',
#    'khaiGrade': '1',
#    'khaiValue': '27',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.016',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.015',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '8',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '3',
#    'pm25Value24': '4',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 09:00',
#    'khaiGrade': '1',
#    'khaiValue': '32',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.019',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.010',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '9',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '4',
#    'pm25Value24': '5',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 08:00',
#    'khaiGrade': '1',
#    'khaiValue': '33',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.020',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.012',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '9',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '3',
#    'pm25Value24': '5',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.003',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 07:00',
#    'khaiGrade': '1',
#    'khaiValue': '28',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.012',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '10',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '5',
#    'pm25Value24': '6',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 06:00',
#    'khaiGrade': '1',
#    'khaiValue': '35',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.009',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.021',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '10',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '4',
#    'pm25Value24': '7',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 05:00',
#    'khaiGrade': '1',
#    'khaiValue': '42',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.007',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.025',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '12',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '4',
#    'pm25Value24': '8',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 04:00',
#    'khaiGrade': '1',
#    'khaiValue': '37',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.006',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.022',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '13',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '5',
#    'pm25Value24': '9',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 03:00',
#    'khaiGrade': '1',
#    'khaiValue': '45',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.006',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '15',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 02:00',
#    'khaiGrade': '2',
#    'khaiValue': '51',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.007',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.031',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '10',
#    'pm10Value24': '16',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '11',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 01:00',
#    'khaiGrade': '1',
#    'khaiValue': '45',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.007',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '13',
#    'pm10Value24': '18',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '7',
#    'pm25Value24': '12',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''}],
#  'parm': {'_returnType': 'json',
#   'coGrade': '',
#   'coValue': '',
#   'dataTerm': 'DAILY',
#   'dataTime': '',
#   'khaiGrade': '',
#   'khaiValue': '',
#   'mangName': '',
#   'no2Grade': '',
#   'no2Value': '',
#   'numOfRows': '10',
#   'o3Grade': '',
#   'o3Value': '',
#   'pageNo': '1',
#   'pm10Grade': '',
#   'pm10Grade1h': '',
#   'pm10Value': '',
#   'pm10Value24': '',
#   'pm25Grade': '',
#   'pm25Grade1h': '',
#   'pm25Value': '',
#   'pm25Value24': '',
#   'resultCode': '',
#   'resultMsg': '',
#   'rnum': 0,
#   'serviceKey': 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ==',
#   'sidoName': '',
#   'so2Grade': '',
#   'so2Value': '',
#   'stationCode': '',
#   'stationName': '강남구',
#   'totalCount': '',
#   'ver': '1.3'},
#  'ArpltnInforInqireSvcVo': {'_returnType': 'json',
#   'coGrade': '',
#   'coValue': '',
#   'dataTerm': 'DAILY',
#   'dataTime': '',
#   'khaiGrade': '',
#   'khaiValue': '',
#   'mangName': '',
#   'no2Grade': '',
#   'no2Value': '',
#   'numOfRows': '10',
#   'o3Grade': '',
#   'o3Value': '',
#   'pageNo': '1',
#   'pm10Grade': '',
#   'pm10Grade1h': '',
#   'pm10Value': '',
#   'pm10Value24': '',
#   'pm25Grade': '',
#   'pm25Grade1h': '',
#   'pm25Value': '',
#   'pm25Value24': '',
#   'resultCode': '',
#   'resultMsg': '',
#   'rnum': 0,
#   'serviceKey': 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ==',
#   'sidoName': '',
#   'so2Grade': '',
#   'so2Value': '',
#   'stationCode': '',
#   'stationName': '강남구',
#   'totalCount': '',
#   'ver': '1.3'},
#  'totalCount': 23}

# %%
import requests
from bs4 import BeautifulSoup
import urllib
BASE_ENDPOINT='http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/'
MY_API_KEY='yeq8B1zUUCHXkJw8ebFFe9%2FZ8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ%3D%3D'
MY_API_KEY=urllib.parse.unquote(MY_API_KEY)
MY_API_KEY
# Out:
# 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ=='

# %%
OPERATION_NAME='getCtprvnRltmMesureDnsty'
endpoint=urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
params={
    'ServiceKey':MY_API_KEY,
    '_returnType': 'json'
    }
resp=requests.get(endpoint,params)
resp
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(resp.content)
soup
# Out:
# <html><body><p>{"ArpltnInforInqireSvcVo":{"_returnType":"json","coGrade":"","coValue":"","dataTerm":"","dataTime":"","khaiGrade":"","khaiValue":"","mangName":"","no2Grade":"","no2Value":"","numOfRows":"10","o3Grade":"","o3Value":"","pageNo":"1","pm10Grade":"","pm10Grade1h":"","pm10Value":"","pm10Value24":"","pm25Grade":"","pm25Grade1h":"","pm25Value":"","pm25Value24":"","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ==","sidoName":"","so2Grade":"","so2Value":"","stationCode":"","stationName":"","totalCount":"","ver":""}}</p></body></html>

# %%
resp.request.url
# Out:
# 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey=yeq8B1zUUCHXkJw8ebFFe9%2FZ8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ%3D%3D&_returnType=json'

# %%
resp.json()
# Out:
# {'ArpltnInforInqireSvcVo': {'_returnType': 'json',
#   'coGrade': '',
#   'coValue': '',
#   'dataTerm': '',
#   'dataTime': '',
#   'khaiGrade': '',
#   'khaiValue': '',
#   'mangName': '',
#   'no2Grade': '',
#   'no2Value': '',
#   'numOfRows': '10',
#   'o3Grade': '',
#   'o3Value': '',
#   'pageNo': '1',
#   'pm10Grade': '',
#   'pm10Grade1h': '',
#   'pm10Value': '',
#   'pm10Value24': '',
#   'pm25Grade': '',
#   'pm25Grade1h': '',
#   'pm25Value': '',
#   'pm25Value24': '',
#   'resultCode': '',
#   'resultMsg': '',
#   'rnum': 0,
#   'serviceKey': 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ==',
#   'sidoName': '',
#   'so2Grade': '',
#   'so2Value': '',
#   'stationCode': '',
#   'stationName': '',
#   'totalCount': '',
#   'ver': ''}}

# %%
# params={
#     'ServiceKey': MY_API_KEY,
#     'numOfRows': 10,
#     'pageNo':1,
#     'stationName':'강남구',
#     'dataTerm':'DAILY',
#     'ver':'1.3',
#     '_returnType': 'json'
# }
BASE_ENDPOINT='http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/'
def get_measure(serviceKey, numOfRows, pageNo, stationName, dataTerm, ver, _returnType):
    OPERATION_NAME='getMsrstnAcctoRltmMesureDnsty'
    endpoint=urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
    
    params={
        'serviceKey': serviceKey,
        'numOfRows': numOfRows,
        'pageNo': pageNo,
        'stationName':stationName,
        'dataTerm':dataTerm,
        'ver': ver,
        '_returnType': _returnType
    }
    resp=requests.get(endpoint,params)
    
    if resp.status_code==200:
        return resp.content
    return False

# %%
measure_list=get_measure(MY_API_KEY, 100, 1, "강남구", 'month','1.0','json')

# %%
import json

# %%
json_list=json.loads(measure_list)
json_list
# Out:
# {'list': [{'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 11:00',
#    'khaiGrade': '1',
#    'khaiValue': '27',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.016',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '6',
#    'pm10Value24': '8',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '2',
#    'pm25Value24': '4',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 10:00',
#    'khaiGrade': '1',
#    'khaiValue': '27',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.016',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.015',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '8',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '3',
#    'pm25Value24': '4',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 09:00',
#    'khaiGrade': '1',
#    'khaiValue': '32',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.019',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.010',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '9',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '4',
#    'pm25Value24': '5',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 08:00',
#    'khaiGrade': '1',
#    'khaiValue': '33',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.020',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.012',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '9',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '3',
#    'pm25Value24': '5',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.003',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 07:00',
#    'khaiGrade': '1',
#    'khaiValue': '28',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.012',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '10',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '5',
#    'pm25Value24': '6',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 06:00',
#    'khaiGrade': '1',
#    'khaiValue': '35',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.009',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.021',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '10',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '4',
#    'pm25Value24': '7',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 05:00',
#    'khaiGrade': '1',
#    'khaiValue': '42',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.007',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.025',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '12',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '4',
#    'pm25Value24': '8',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 04:00',
#    'khaiGrade': '1',
#    'khaiValue': '37',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.006',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.022',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '13',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '5',
#    'pm25Value24': '9',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 03:00',
#    'khaiGrade': '1',
#    'khaiValue': '45',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.006',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '9',
#    'pm10Value24': '15',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 02:00',
#    'khaiGrade': '2',
#    'khaiValue': '51',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.007',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.031',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '10',
#    'pm10Value24': '16',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '11',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 01:00',
#    'khaiGrade': '1',
#    'khaiValue': '45',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.007',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '13',
#    'pm10Value24': '18',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '7',
#    'pm25Value24': '12',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 24:00',
#    'khaiGrade': '2',
#    'khaiValue': '53',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.008',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.033',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '10',
#    'pm10Value24': '19',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '7',
#    'pm25Value24': '14',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 23:00',
#    'khaiGrade': '2',
#    'khaiValue': '53',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.010',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.033',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '10',
#    'pm10Value24': '21',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '7',
#    'pm25Value24': '15',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 22:00',
#    'khaiGrade': '2',
#    'khaiValue': '56',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.009',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.035',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '13',
#    'pm10Value24': '24',
#    'pm25Grade': '2',
#    'pm25Grade1h': '1',
#    'pm25Value': '8',
#    'pm25Value24': '18',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 21:00',
#    'khaiGrade': '2',
#    'khaiValue': '61',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.009',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.034',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '19',
#    'pm10Value24': '27',
#    'pm25Grade': '2',
#    'pm25Grade1h': '1',
#    'pm25Value': '12',
#    'pm25Value24': '20',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 20:00',
#    'khaiGrade': '2',
#    'khaiValue': '66',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.010',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.035',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '22',
#    'pm10Value24': '30',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '16',
#    'pm25Value24': '22',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 19:00',
#    'khaiGrade': '2',
#    'khaiValue': '72',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.012',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.043',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '26',
#    'pm10Value24': '33',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '21',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 18:00',
#    'khaiGrade': '2',
#    'khaiValue': '80',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.066',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '28',
#    'pm10Value24': '35',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '22',
#    'pm25Value24': '25',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 17:00',
#    'khaiGrade': '2',
#    'khaiValue': '77',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.062',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '33',
#    'pm10Value24': '36',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '24',
#    'pm25Value24': '25',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 16:00',
#    'khaiGrade': '2',
#    'khaiValue': '88',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.076',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '40',
#    'pm10Value24': '37',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '31',
#    'pm25Value24': '25',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 15:00',
#    'khaiGrade': '2',
#    'khaiValue': '95',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.013',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.084',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '42',
#    'pm10Value24': '34',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '32',
#    'pm25Value24': '25',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 14:00',
#    'khaiGrade': '2',
#    'khaiValue': '94',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.012',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.083',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '31',
#    'pm10Value24': '33',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '25',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 13:00',
#    'khaiGrade': '2',
#    'khaiValue': '87',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.011',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.074',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '',
#    'pm10Value': '-',
#    'pm10Value24': '32',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '23',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 12:00',
#    'khaiGrade': '2',
#    'khaiValue': '75',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.011',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.060',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '28',
#    'pm10Value24': '33',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '21',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.007',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 11:00',
#    'khaiGrade': '2',
#    'khaiValue': '72',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.052',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '31',
#    'pm10Value24': '35',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '22',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 10:00',
#    'khaiGrade': '2',
#    'khaiValue': '72',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.039',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '29',
#    'pm10Value24': '36',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '21',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 09:00',
#    'khaiGrade': '2',
#    'khaiValue': '72',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '40',
#    'pm10Value24': '36',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '28',
#    'pm25Value24': '24',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 08:00',
#    'khaiGrade': '2',
#    'khaiValue': '69',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.018',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.024',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '41',
#    'pm10Value24': '35',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '30',
#    'pm25Value24': '23',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 07:00',
#    'khaiGrade': '2',
#    'khaiValue': '69',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.016',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.024',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '43',
#    'pm10Value24': '33',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '32',
#    'pm25Value24': '23',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 06:00',
#    'khaiGrade': '2',
#    'khaiValue': '66',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.013',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.030',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '38',
#    'pm10Value24': '32',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '30',
#    'pm25Value24': '22',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 05:00',
#    'khaiGrade': '2',
#    'khaiValue': '66',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.010',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.044',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '33',
#    'pm10Value24': '31',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '26',
#    'pm25Value24': '22',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 04:00',
#    'khaiGrade': '2',
#    'khaiValue': '64',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.009',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.042',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '32',
#    'pm10Value24': '31',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '24',
#    'pm25Value24': '21',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 03:00',
#    'khaiGrade': '2',
#    'khaiValue': '61',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.039',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '2',
#    'pm10Value': '43',
#    'pm10Value24': '30',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '30',
#    'pm25Value24': '20',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 02:00',
#    'khaiGrade': '2',
#    'khaiValue': '59',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.030',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.022',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '2',
#    'pm10Value': '31',
#    'pm10Value24': '26',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '23',
#    'pm25Value24': '19',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-09 01:00',
#    'khaiGrade': '2',
#    'khaiValue': '65',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.039',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.016',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '27',
#    'pm10Value24': '23',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '20',
#    'pm25Value24': '17',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 24:00',
#    'khaiGrade': '2',
#    'khaiValue': '58',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.035',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.021',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '24',
#    'pm10Value24': '22',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '18',
#    'pm25Value24': '16',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 23:00',
#    'khaiGrade': '2',
#    'khaiValue': '58',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.022',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.039',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '18',
#    'pm10Value24': '22',
#    'pm25Grade': '2',
#    'pm25Grade1h': '1',
#    'pm25Value': '15',
#    'pm25Value24': '16',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 22:00',
#    'khaiGrade': '2',
#    'khaiValue': '63',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.018',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.045',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '18',
#    'pm10Value24': '22',
#    'pm25Grade': '2',
#    'pm25Grade1h': '1',
#    'pm25Value': '13',
#    'pm25Value24': '16',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 21:00',
#    'khaiGrade': '2',
#    'khaiValue': '68',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.051',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '18',
#    'pm10Value24': '25',
#    'pm25Grade': '2',
#    'pm25Grade1h': '1',
#    'pm25Value': '15',
#    'pm25Value24': '17',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 20:00',
#    'khaiGrade': '2',
#    'khaiValue': '68',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.020',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.052',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '25',
#    'pm10Value24': '29',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '19',
#    'pm25Value24': '18',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 19:00',
#    'khaiGrade': '2',
#    'khaiValue': '70',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.021',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.054',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '',
#    'pm10Value': '-',
#    'pm10Value24': '29',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '19',
#    'pm25Value24': '17',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 18:00',
#    'khaiGrade': '2',
#    'khaiValue': '73',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.022',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.058',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '2',
#    'pm10Value': '34',
#    'pm10Value24': '27',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '23',
#    'pm25Value24': '16',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 17:00',
#    'khaiGrade': '2',
#    'khaiValue': '73',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.025',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.057',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '2',
#    'pm10Value': '45',
#    'pm10Value24': '24',
#    'pm25Grade': '1',
#    'pm25Grade1h': '2',
#    'pm25Value': '24',
#    'pm25Value24': '14',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 16:00',
#    'khaiGrade': '2',
#    'khaiValue': '71',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.024',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.055',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '28',
#    'pm10Value24': '19',
#    'pm25Grade': '1',
#    'pm25Grade1h': '2',
#    'pm25Value': '16',
#    'pm25Value24': '11',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 15:00',
#    'khaiGrade': '2',
#    'khaiValue': '71',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.055',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '19',
#    'pm10Value24': '18',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '11',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 14:00',
#    'khaiGrade': '2',
#    'khaiValue': '68',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.051',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '20',
#    'pm10Value24': '18',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '11',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 13:00',
#    'khaiGrade': '2',
#    'khaiValue': '61',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.043',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '17',
#    'pm10Value24': '17',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '9',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 12:00',
#    'khaiGrade': '2',
#    'khaiValue': '58',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.039',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '19',
#    'pm10Value24': '17',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '12',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 11:00',
#    'khaiGrade': '2',
#    'khaiValue': '57',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.038',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '20',
#    'pm10Value24': '16',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '11',
#    'pm25Value24': '10',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 10:00',
#    'khaiGrade': '1',
#    'khaiValue': '48',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.019',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.029',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '16',
#    'pm10Value24': '15',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '8',
#    'pm25Value24': '9',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 09:00',
#    'khaiGrade': '1',
#    'khaiValue': '43',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.019',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.026',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '17',
#    'pm10Value24': '15',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '11',
#    'pm25Value24': '9',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 08:00',
#    'khaiGrade': '1',
#    'khaiValue': '47',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.017',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.028',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '15',
#    'pm10Value24': '14',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '10',
#    'pm25Value24': '9',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 07:00',
#    'khaiGrade': '1',
#    'khaiValue': '47',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.016',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.028',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '16',
#    'pm10Value24': '14',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '10',
#    'pm25Value24': '9',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 06:00',
#    'khaiGrade': '1',
#    'khaiValue': '45',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '14',
#    'pm10Value24': '14',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '9',
#    'pm25Value24': '8',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 05:00',
#    'khaiGrade': '1',
#    'khaiValue': '47',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.012',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.028',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '14',
#    'pm10Value24': '14',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '9',
#    'pm25Value24': '8',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 04:00',
#    'khaiGrade': '1',
#    'khaiValue': '50',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.012',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.030',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '16',
#    'pm10Value24': '13',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '10',
#    'pm25Value24': '7',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 03:00',
#    'khaiGrade': '1',
#    'khaiValue': '45',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.013',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '16',
#    'pm10Value24': '12',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '9',
#    'pm25Value24': '7',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 02:00',
#    'khaiGrade': '1',
#    'khaiValue': '48',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.016',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.029',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '14',
#    'pm10Value24': '12',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '9',
#    'pm25Value24': '6',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-08 01:00',
#    'khaiGrade': '1',
#    'khaiValue': '47',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.019',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.028',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '14',
#    'pm10Value24': '11',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '7',
#    'pm25Value24': '6',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 24:00',
#    'khaiGrade': '2',
#    'khaiValue': '58',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.011',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.040',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '12',
#    'pm10Value24': '10',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '8',
#    'pm25Value24': '6',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 23:00',
#    'khaiGrade': '2',
#    'khaiValue': '63',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.009',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.046',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '13',
#    'pm10Value24': '10',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '7',
#    'pm25Value24': '5',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 22:00',
#    'khaiGrade': '2',
#    'khaiValue': '61',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.014',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.043',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '11',
#    'pm10Value24': '9',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '4',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 21:00',
#    'khaiGrade': '2',
#    'khaiValue': '63',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.016',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.045',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '12',
#    'pm10Value24': '8',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '4',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 20:00',
#    'khaiGrade': '2',
#    'khaiValue': '64',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.013',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.047',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '10',
#    'pm10Value24': '8',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '6',
#    'pm25Value24': '3',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 19:00',
#    'khaiGrade': '2',
#    'khaiValue': '63',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.045',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '8',
#    'pm10Value24': '7',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '2',
#    'pm25Value24': '3',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 18:00',
#    'khaiGrade': '2',
#    'khaiValue': '63',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.013',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.046',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '6',
#    'pm10Value24': '7',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '2',
#    'pm25Value24': '3',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 17:00',
#    'khaiGrade': '2',
#    'khaiValue': '57',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.011',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.038',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '7',
#    'pm10Value24': '7',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '1',
#    'pm25Value24': '3',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 16:00',
#    'khaiGrade': '2',
#    'khaiValue': '60',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.012',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.042',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '8',
#    'pm10Value24': '7',
#    'pm25Grade': '1',
# ...
#    'pm25Value': '10',
#    'pm25Value24': '20',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 03:00',
#    'khaiGrade': '2',
#    'khaiValue': '69',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.005',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.045',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '22',
#    'pm10Value24': '34',
#    'pm25Grade': '2',
#    'pm25Grade1h': '1',
#    'pm25Value': '12',
#    'pm25Value24': '23',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 02:00',
#    'khaiGrade': '2',
#    'khaiValue': '77',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.006',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.044',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '23',
#    'pm10Value24': '38',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '16',
#    'pm25Value24': '26',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-07 01:00',
#    'khaiGrade': '2',
#    'khaiValue': '82',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.008',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.045',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '25',
#    'pm10Value24': '41',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '17',
#    'pm25Value24': '28',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 24:00',
#    'khaiGrade': '2',
#    'khaiValue': '87',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.010',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.037',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '1',
#    'pm10Value': '29',
#    'pm10Value24': '44',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '22',
#    'pm25Value24': '30',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 23:00',
#    'khaiGrade': '2',
#    'khaiValue': '90',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.032',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '36',
#    'pm10Value24': '48',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '27',
#    'pm25Value24': '31',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.4',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 22:00',
#    'khaiGrade': '2',
#    'khaiValue': '92',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.013',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.037',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '35',
#    'pm10Value24': '52',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '24',
#    'pm25Value24': '32',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 21:00',
#    'khaiGrade': '2',
#    'khaiValue': '95',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.012',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.046',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '43',
#    'pm10Value24': '55',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '28',
#    'pm25Value24': '33',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 20:00',
#    'khaiGrade': '2',
#    'khaiValue': '97',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.020',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.035',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '54',
#    'pm10Value24': '57',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '38',
#    'pm25Value24': '34',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 19:00',
#    'khaiGrade': '2',
#    'khaiValue': '97',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.024',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.036',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '57',
#    'pm10Value24': '58',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '40',
#    'pm25Value24': '34',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 18:00',
#    'khaiGrade': '2',
#    'khaiValue': '97',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.031',
#    'numOfRows': '10',
#    'o3Grade': '2',
#    'o3Value': '0.031',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '58',
#    'pm10Value24': '58',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '39',
#    'pm25Value24': '34',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.7',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 17:00',
#    'khaiGrade': '2',
#    'khaiValue': '95',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.045',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.019',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '70',
#    'pm10Value24': '56',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '45',
#    'pm25Value24': '33',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 16:00',
#    'khaiGrade': '2',
#    'khaiValue': '87',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.040',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.025',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '66',
#    'pm10Value24': '55',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '42',
#    'pm25Value24': '30',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 15:00',
#    'khaiGrade': '2',
#    'khaiValue': '85',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.039',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.027',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '67',
#    'pm10Value24': '52',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '42',
#    'pm25Value24': '29',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.007',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 14:00',
#    'khaiGrade': '2',
#    'khaiValue': '79',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.037',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.029',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '57',
#    'pm10Value24': '50',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '37',
#    'pm25Value24': '27',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 13:00',
#    'khaiGrade': '2',
#    'khaiValue': '77',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.038',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.022',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '58',
#    'pm10Value24': '47',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '33',
#    'pm25Value24': '26',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.007',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 12:00',
#    'khaiGrade': '2',
#    'khaiValue': '74',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.038',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.020',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '56',
#    'pm10Value24': '45',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '37',
#    'pm25Value24': '25',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 11:00',
#    'khaiGrade': '2',
#    'khaiValue': '78',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.047',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.009',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '58',
#    'pm10Value24': '41',
#    'pm25Grade': '2',
#    'pm25Grade1h': '3',
#    'pm25Value': '39',
#    'pm25Value24': '25',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.006',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 10:00',
#    'khaiGrade': '2',
#    'khaiValue': '71',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.043',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.009',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '50',
#    'pm10Value24': '38',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '33',
#    'pm25Value24': '23',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.007',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.6',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 09:00',
#    'khaiGrade': '2',
#    'khaiValue': '69',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.039',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.009',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '46',
#    'pm10Value24': '35',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '30',
#    'pm25Value24': '23',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.5',
#    'dataTerm': '',
#    'dataTime': '2019-06-06 08:00',
#    'khaiGrade': '2',
#    'khaiValue': '66',
#    'mangName': '도시대기',
#    'no2Grade': '2',
#    'no2Value': '0.033',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.008',
#    'pageNo': '1',
#    'pm10Grade': '2',
#    'pm10Grade1h': '2',
#    'pm10Value': '37',
#    'pm10Value24': '32',
#    'pm25Grade': '2',
#    'pm25Grade1h': '2',
#    'pm25Value': '25',
#    'pm25Value24': '22',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.005',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''}],
#  'parm': {'_returnType': 'json',
#   'coGrade': '',
#   'coValue': '',
#   'dataTerm': 'MONTH',
#   'dataTime': '',
#   'khaiGrade': '',
#   'khaiValue': '',
#   'mangName': '',
#   'no2Grade': '',
#   'no2Value': '',
#   'numOfRows': '100',
#   'o3Grade': '',
#   'o3Value': '',
#   'pageNo': '1',
#   'pm10Grade': '',
#   'pm10Grade1h': '',
#   'pm10Value': '',
#   'pm10Value24': '',
#   'pm25Grade': '',
#   'pm25Grade1h': '',
#   'pm25Value': '',
#   'pm25Value24': '',
#   'resultCode': '',
#   'resultMsg': '',
#   'rnum': 0,
#   'serviceKey': 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ==',
#   'sidoName': '',
#   'so2Grade': '',
#   'so2Value': '',
#   'stationCode': '',
#   'stationName': '강남구',
#   'totalCount': '',
#   'ver': '1.0'},
#  'ArpltnInforInqireSvcVo': {'_returnType': 'json',
#   'coGrade': '',
#   'coValue': '',
#   'dataTerm': 'MONTH',
#   'dataTime': '',
#   'khaiGrade': '',
#   'khaiValue': '',
#   'mangName': '',
#   'no2Grade': '',
#   'no2Value': '',
#   'numOfRows': '100',
#   'o3Grade': '',
#   'o3Value': '',
#   'pageNo': '1',
#   'pm10Grade': '',
#   'pm10Grade1h': '',
#   'pm10Value': '',
#   'pm10Value24': '',
#   'pm25Grade': '',
#   'pm25Grade1h': '',
#   'pm25Value': '',
#   'pm25Value24': '',
#   'resultCode': '',
#   'resultMsg': '',
#   'rnum': 0,
#   'serviceKey': 'yeq8B1zUUCHXkJw8ebFFe9/Z8MTawntjIurYkAVVZtJwOQ0cZs03dYWmOEWfcLgPBck1rkRJcC1vDa0lmtA3oQ==',
#   'sidoName': '',
#   'so2Grade': '',
#   'so2Value': '',
#   'stationCode': '',
#   'stationName': '강남구',
#   'totalCount': '',
#   'ver': '1.0'},
#  'totalCount': 743}

# %%
temp_dict={
    'name':'atilda',
    'loc': 'Seoul',
    'friends':['yoonsoo','teddy']
}

# %%
file=json.dumps(temp_dict)

# %%
file
#키가 따옴표로 묶인 것이 json 타입
# Out:
# '{"name": "atilda", "loc": "Seoul", "friends": ["yoonsoo", "teddy"]}'
