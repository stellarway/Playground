# %%
import requests
from bs4 import BeautifulSoup

# %%
url="https://search.naver.com/search.naver"
query="역삼맛집"
params=dict(
    oquery="멀티캠퍼스",
    query=query
)
    
resp=requests.get(url,params=params)
resp
# Out:
# <Response [200]>

# %%
for i in range(1,100001):
    import time
    import random
    time.sleep(random.randint(1,6))
    print(i,"회 실행했습니다.",resp)
# Out:
# 1 회 실행했습니다. <Response [200]>
# 2 회 실행했습니다. <Response [200]>
# 3 회 실행했습니다. <Response [200]>
# 4 회 실행했습니다. <Response [200]>
# 5 회 실행했습니다. <Response [200]>
# 6 회 실행했습니다. <Response [200]>
# 7 회 실행했습니다. <Response [200]>
# 8 회 실행했습니다. <Response [200]>
# 9 회 실행했습니다. <Response [200]>
# 10 회 실행했습니다. <Response [200]>
# 11 회 실행했습니다. <Response [200]>
# 12 회 실행했습니다. <Response [200]>
# 13 회 실행했습니다. <Response [200]>
# 14 회 실행했습니다. <Response [200]>
# 15 회 실행했습니다. <Response [200]>
# 16 회 실행했습니다. <Response [200]>
# 17 회 실행했습니다. <Response [200]>
# 18 회 실행했습니다. <Response [200]>
# 19 회 실행했습니다. <Response [200]>
# 20 회 실행했습니다. <Response [200]>
# 21 회 실행했습니다. <Response [200]>
# 22 회 실행했습니다. <Response [200]>
# 23 회 실행했습니다. <Response [200]>
# 24 회 실행했습니다. <Response [200]>
# 25 회 실행했습니다. <Response [200]>
# 26 회 실행했습니다. <Response [200]>
# 27 회 실행했습니다. <Response [200]>
# 28 회 실행했습니다. <Response [200]>
# 29 회 실행했습니다. <Response [200]>
# 30 회 실행했습니다. <Response [200]>
# 31 회 실행했습니다. <Response [200]>
# ...
