# %% [markdown]
# # Decision Tree

# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import graphviz # pip install

# %%
DATASET_DIR = os.path.join(os.path.dirname(os.getcwd()), 'datasets')

# %%
red_file = os.path.join(DATASET_DIR, 'winequality-red.csv')
white_file = os.path.join(DATASET_DIR, 'winequality-white.csv')

# %%
wine_red = pd.read_csv(red_file, sep=';')
wine_white = pd.read_csv(white_file, sep=';')

# %%
wine_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
len(wine_red), len(wine_white)
# Out:
# (1599, 4898)

# %%
wine_red.head()

wine_white.head()

len(wine_red), len(wine_white)
# Out:
# (1599, 4898)

# %% [markdown]
# ## Classification

# %% [markdown]
# ### 1. Feature_n: 2(volatile acidity, sulphates), Binary Problem

# %%
new_red = wine_red.copy()
new_red['is_red'] = 1
new_white = wine_white.copy()
new_white['is_red'] = 0

wine = new_red.append(new_white, ignore_index=True)

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1

# %%
wine.tail(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  is_red
# 6495     12.8        7       0
# 6496     11.8        6       0

# %%
X = wine[['volatile acidity', 'sulphates']]
y = wine['is_red']

# %% [markdown]
# ##### split train&test

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, stratify=wine['is_red'], random_state=42)

# %%
red_index = train_y[train_y==1].index
white_index = train_y[train_y==0].index
plt.figure(figsize=(15,15))
plt.scatter(x=train_X.loc[white_index, 'volatile acidity'], y=train_X.loc[white_index, 'sulphates'], color='r', alpha=0.3)

plt.scatter(x=train_X.loc[red_index, 'volatile acidity'], y=train_X.loc[red_index, 'sulphates'], color='g',  alpha=0.3)

plt.show()

# %%
import sys
sys.path.append
# Out:
# <function list.append(object, /)>

# %%
from sklearn import tree

"""
DecisionTreeClassifier(criterion=’gini’, splitter=’best’, max_depth=None, min_samples_split=2, min_samples_leaf=1, 
                       min_weight_fraction_leaf=0.0, max_features=None, max_leaf_nodes=None, 
                       min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)

# scikit-learn uses an optimised version of the CART algorithm.
                       
# criterion: entropy or gini
The function to measure the quality of a split. 
Supported criteria are “gini” for the Gini impurity and “entropy” for the information gain.

# random_state: 난수값

# max_depth : int or None, optional (default=None)
The maximum depth of the tree. 
If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split sample

# min_samples_split: 분할 되기 위해 노드가 가져야 하는 최소 샘플 수 
# min_samples_leaf: 리프 노드가 가지고 있어야 할 최소 샘플 수
# max_leaf_nodes: 리프 노드의 최대 수
# max_features: 노드에서 분할에 사용할 특성의 최대 수
"""


clf = tree.DecisionTreeClassifier('entropy', max_depth=2)
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dot_data = tree.export_graphviz(
    clf, out_file=None, 
    max_depth=2, 
    feature_names=list(X.columns.values), 
    filled=True, 
    rounded=True)
graphviz.Source(dot_data)

# %%
clf.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
clf.max_features_
# Out:
# 2

# %%
clf.n_classes_
# Out:
# 2

# %%
clf.n_features_
# Out:
# 2

# %%
dir(clf)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_estimator_type',
#  '_get_param_names',
#  '_validate_X_predict',
#  'apply',
#  'class_weight',
#  'classes_',
#  'criterion',
#  'decision_path',
#  'feature_importances_',
#  'fit',
#  'get_params',
#  'max_depth',
#  'max_features',
#  'max_features_',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_weight_fraction_leaf',
#  'n_classes_',
#  'n_features_',
#  'n_outputs_',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'presort',
#  'random_state',
#  'score',
#  'set_params',
#  'splitter',
#  'tree_']

# %%
# Returns the mean accuracy on the given test data and labels.
clf.score(train_X,train_y)
# Out:
# 0.8846469622331691

# %%
clf.score(test_X, test_y)
# Out:
# 0.8898461538461538

# %%
train_X.iloc[1]
# Out:
# volatile acidity    0.27
# sulphates           0.42
# Name: 5370, dtype: float64

# %%
print(clf.decision_path(train_X.iloc[:1]))
# decision_path: 어떻게 찾아가냐에 따른 결정 경로
# Out:
#   (0, 0)	1
#   (0, 1)	1
#   (0, 3)	1

# %%
# 
# (a, b) = (X_index, node_index)
# 어떤 트리를 따라가느냐
m = clf.decision_path(X.loc[:1])
print(m)
# Out:
#   (0, 0)	1
#   (0, 4)	1
#   (0, 6)	1
#   (1, 0)	1
#   (1, 4)	1
#   (1, 6)	1

# %%
clf.predict(train_X.iloc[:1])
# Out:
# array([0], dtype=int64)

# %%
# Predict class log-probabilities of the input samples X.
clf.predict_log_proba(X)
# proba: 후보 value들의 합을 나눈 것
# Out:
# array([[-1.7225648 , -0.19675417],
#        [-1.7225648 , -0.19675417],
#        [-1.7225648 , -0.19675417],
#        ...,
#        [-0.02971023, -3.53108229],
#        [-0.02971023, -3.53108229],
#        [-0.02971023, -3.53108229]])

# %%
# The predicted class probability is the fraction of samples of the same class in a leaf.
clf.predict_proba(train_X)
# Out:
# array([[0.64208243, 0.35791757],
#        [0.97072678, 0.02927322],
#        [0.97072678, 0.02927322],
#        ...,
#        [0.97072678, 0.02927322],
#        [0.97072678, 0.02927322],
#        [0.97072678, 0.02927322]])

# %%
clf.get_depth()
# 트리의 깊이
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a319d8c798b8> in <module>
# ----> 1 clf.get_depth()
#       2 # 트리의 깊이
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'get_depth'

# %%
clf.apply(train_X.iloc[:10]) # node의 위치
# 트리를 진행 시켰을 때 어떤 리프에 안착하느냐를 나타내줌
# Out:
# array([3, 2, 2, 3, 6, 2, 2, 2, 6, 2], dtype=int64)

# %%
clf.predict(X)
#돌렸을 때 결과값
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ### parameter 조정 # depth3

# %%
from sklearn import tree

"""
DecisionTreeClassifier(criterion=’gini’, splitter=’best’, max_depth=None, min_samples_split=2, min_samples_leaf=1, 
                       min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, 
                       min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)

# scikit-learn uses an optimised version of the CART algorithm.
                       
# criterion: entropy or gini
The function to measure the quality of a split. 
Supported criteria are “gini” for the Gini impurity and “entropy” for the information gain.

# max_depth : int or None, optional (default=None)
The maximum depth of the tree. 
If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split sample

# min_samples_split: 분할 되기 위해 노드가 가져야 하는 최소 샘플 수 
# min_samples_leaf: 리프 노드가 가지고 있어야 할 최소 샘플 수
# max_leaf_nodes: 리프 노드의 최대 수
# max_features: 노드에서 분할에 사용할 특성의 최대 수
"""
clf = tree.DecisionTreeClassifier('entropy', max_depth=5)
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dot_data = tree.export_graphviz(clf, out_file=None, max_depth=5, feature_names=list(X.columns.values), filled=True, rounded=True)
graphviz.Source(dot_data)

# %%
clf.score(train_X,train_y)
# Out:
# 0.9614121510673235

# %%
clf.score(test_X, test_y)
# Out:
# 0.8996923076923077

# %%
from sklearn import tree


clf = tree.DecisionTreeClassifier('entropy', max_depth=3, )
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn import tree


clf = tree.DecisionTreeClassifier('entropy', max_depth=5)
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
clf.score(train_X,train_y), clf.score(test_X, test_y)
# Out:
# (0.9205665024630542, 0.9126153846153846)

# %%
clf.predict(test_X)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Feature importance is calculated as the decrease in node impurity weighted by the probability of reaching that node. 
# The node probability can be calculated by the number of samples that reach the node, divided by the total number of samples. 
# The higher the value the more important the feature.

X.columns, clf.feature_importances_
# Out:
# (Index(['volatile acidity', 'sulphates'], dtype='object'),
#  array([0.70940971, 0.29059029]))

# %%
test_y[:3]
# Out:
# 3128    0
# 4224    0
# 6431    0
# Name: is_red, dtype: int64

# %% [markdown]
# ### 파라미터 조정 # max_leaf_nodes

# %%
from sklearn import tree

"""
DecisionTreeClassifier(criterion=’gini’, splitter=’best’, max_depth=None, min_samples_split=2, min_samples_leaf=1, 
                       min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, 
                       min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)

# scikit-learn uses an optimised version of the CART algorithm.
                       
# criterion: entropy or gini
The function to measure the quality of a split. 
Supported criteria are “gini” for the Gini impurity and “entropy” for the information gain.

# max_depth : int or None, optional (default=None)
The maximum depth of the tree. 
If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split sample

# min_samples_split: 분할 되기 위해 노드가 가져야 하는 최소 샘플 수 
# min_samples_leaf: 리프 노드가 가지고 있어야 할 최소 샘플 수
# max_leaf_nodes: 리프 노드의 최대 수
# max_features: 노드에서 분할에 사용할 특성의 최대 수
"""
clf = tree.DecisionTreeClassifier('entropy',  max_depth=3)

clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
clf.score(train_X, train_y)
# Out:
# 0.9010673234811166

# %%
clf.score(test_X, test_y)
# Out:
# 0.9064615384615384

# %%
dot_data = tree.export_graphviz(clf, out_file=None, max_depth=5, feature_names=list(X.columns.values), filled=True, rounded=True)
graphviz.Source(dot_data)

# %% [markdown]
# # 실습1: depth가 5이고  max_leaf_nodes가 10인 트리를 만들고 학습시키시오.

# %%
# clf = tree.DecisionTreeClassifier('entropy',max_depth=5, max_leaf_nodes=10)

# %%
from sklearn import tree

# %%
clf=tree.DecisionTreeClassifier('entropy', max_depth=5, max_leaf_nodes=10)
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=10,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dot_data = tree.export_graphviz(clf, out_file=None, max_depth=2, feature_names=list(X.columns.values), filled=True, rounded=True)
graphviz.Source(dot_data)

# %% [markdown]
# $$Gini = 1-\sum_jp_j^2$$

# %% [markdown]
# ### Overfitting  # 이전 예제에 비해 비교적

# %%
clf = tree.DecisionTreeClassifier('entropy')
# depth가 없다!! 척도만 entropy로 지정되어 있다.
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
train_X.head()
# Out:
#       volatile acidity  sulphates
# 5369              0.27       0.65
# 5370              0.27       0.42
# 3978              0.27       0.63
# 281               0.27       1.08
# 553               1.04       0.62

# %%
m=clf.decision_path(train_X)

# %%
clf = tree.DecisionTreeClassifier('entropy')
clf.fit(train_X, train_y)
clf.score(test_X, test_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 0.8996923076923077

# %%
clf.score(train_X, train_y)
# Out:
# 0.9614121510673235

# %% [markdown]
# ### 1. depth제한 X:  Feature_n: 2(volatile acidity, sulphates), Binary Problem

# %%
clf = tree.DecisionTreeClassifier('entropy')
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dot_data = tree.export_graphviz(clf, out_file=None, feature_names=list(X.columns.values), filled=True, rounded=True)
graphviz.Source(dot_data)

# %%
clf.score(train_X, train_y)
# Out:
# 0.9614121510673235

# %%
clf.score(test_X, test_y)
# Out:
# 0.8996923076923077

# %%
clf.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
clf.max_features_
# Out:
# 2

# %%
clf.n_classes_
# Out:
# 2

# %%
clf.n_features_
# Out:
# 2

# %%
clf.get_n_leaves()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-0fc5669b807a> in <module>
# ----> 1 clf.get_n_leaves()
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'get_n_leaves'

# %%
# Returns the mean accuracy on the given test data and labels.
clf.score(train_X,train_y)
# Out:
# 0.9614121510673235

# %%
clf.score(test_X, test_y)
# Out:
# 0.8996923076923077

# %%
train_X.iloc[1]
# Out:
# volatile acidity    0.27
# sulphates           0.42
# Name: 5370, dtype: float64

# %%
# 
# (a, b) = (X_index, node_index)
m = clf.decision_path(X.loc[:1])
print(m)
# Out:
#   (0, 0)	1
#   (0, 560)	1
#   (0, 742)	1
#   (0, 960)	1
#   (0, 1072)	1
#   (0, 1073)	1
#   (0, 1135)	1
#   (0, 1136)	1
#   (0, 1142)	1
#   (1, 0)	1
#   (1, 560)	1
#   (1, 742)	1
#   (1, 960)	1
#   (1, 1072)	1
#   (1, 1073)	1
#   (1, 1135)	1
#   (1, 1136)	1
#   (1, 1142)	1

# %%
# Predict class log-probabilities of the input samples X.
clf.predict_log_proba(X)
# Out:
# array([[-1.7225648 , -0.19675417],
#        [-1.7225648 , -0.19675417],
#        [-1.7225648 , -0.19675417],
#        ...,
#        [-0.02971023, -3.53108229],
#        [-0.02971023, -3.53108229],
#        [-0.02971023, -3.53108229]])

# %%
# The predicted class probability is the fraction of samples of the same class in a leaf.
clf.predict_proba(X)
# Out:
# array([[0.17860747, 0.82139253],
#        [0.17860747, 0.82139253],
#        [0.17860747, 0.82139253],
#        ...,
#        [0.97072678, 0.02927322],
#        [0.97072678, 0.02927322],
#        [0.97072678, 0.02927322]])

# %%
clf.get_depth()
# Out:
# 2

# %%
clf.apply(X.loc[:10]) # node의 위치
# Out:
# array([6, 6, 6, 2, 6, 6, 5, 5, 6, 6, 6])

# %%
clf.predict(X)
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# # 2. Feature: All, y= red or white

# %%
new_red = wine_red.copy()
new_red['is_red'] = 1
new_white = wine_white.copy()
new_white['is_red'] = 0

wine = new_red.append(new_white, ignore_index=True)

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1

# %%
wine.tail(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  is_red
# 6495     12.8        7       0
# 6496     11.8        6       0

# %%
X = wine.drop('is_red', axis=1)
y = wine['is_red']

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, stratify=wine['is_red'], random_state=42)

# %%
from sklearn import tree

"""
DecisionTreeClassifier(criterion=’gini’, splitter=’best’, max_depth=None, min_samples_split=2, min_samples_leaf=1, 
                       min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, 
                       min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)

# scikit-learn uses an optimised version of the CART algorithm.
                       
# criterion: entropy or gini
The function to measure the quality of a split. 
Supported criteria are “gini” for the Gini impurity and “entropy” for the information gain.

# max_depth : int or None, optional (default=None)
The maximum depth of the tree. 
If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split sample

# random_state: 난수값

# min_samples_split: 분할 되기 위해 노드가 가져야 하는 최소 샘플 수 
# min_samples_leaf: 리프 노드가 가지고 있어야 할 최소 샘플 수
# max_leaf_nodes: 리프 노드의 최대 수
# max_features: 노드에서 분할에 사용할 특성의 최대 수 

# max_features : int, float, string or None, optional (default=”auto”)
The number of features to consider when looking for the best split:

If int, then consider max_features features at each split.
If float, then max_features is a fraction and int(max_features * n_features) features are considered at each split.
If “auto”, then max_features=sqrt(n_features).
If “sqrt”, then max_features=sqrt(n_features) (same as “auto”).
If “log2”, then max_features=log2(n_features).
If None, then max_features=n_features.

"""
clf = tree.DecisionTreeClassifier('entropy', max_features=3, random_state=42)
# max_features 는 분할할 때 사용하는 속성의 최대 수 / 이게 커지면 시간이 오래 걸린다
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=3, max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=42, splitter='best')

# %%
clf.score(train_X, train_y)
# Out:
# 0.9997947454844006

# %%
clf.score(test_X, test_y)
# Out:
# 0.984

# %%
dot_data = tree.export_graphviz(clf, out_file=None, max_depth=3, feature_names=list(X.columns.values), filled=True, rounded=True)
graphviz.Source(dot_data)

# %%
list(zip(X.columns, clf.feature_importances_))
# Out:
# [('fixed acidity', 0.05573847798308888),
#  ('volatile acidity', 0.12340887255782702),
#  ('citric acid', 0.006442317782771258),
#  ('residual sugar', 0.013796706756046351),
#  ('chlorides', 0.5622390116865462),
#  ('free sulfur dioxide', 0.020904828884168877),
#  ('total sulfur dioxide', 0.09944469426984785),
#  ('density', 0.028862054959159368),
#  ('pH', 0.030586537602229763),
#  ('sulphates', 0.04151629696680267),
#  ('alcohol', 0.013599055438990619),
#  ('quality', 0.0034611451125211015)]

# %%
clf.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
clf.max_features_
# Out:
# 3

# %%
clf.n_classes_
# Out:
# 2

# %%
clf.n_features_
# Out:
# 12

# %% [markdown]
# # 3. Quality 예측

# %%
new_red = wine_red.copy()
new_white = wine_white.copy()

# %%
X = new_red.drop('quality', axis=1)
y = new_red['quality']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, stratify=y, random_state=42, test_size=.2)

# %%
train_y.head()
# Out:
# 1542    6
# 1558    5
# 344     6
# 924     5
# 971     6
# Name: quality, dtype: int64

# %%
from sklearn import tree

"""
DecisionTreeClassifier(criterion=’gini’, splitter=’best’, max_depth=None, min_samples_split=2, min_samples_leaf=1, 
                       min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, 
                       min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)

# scikit-learn uses an optimised version of the CART algorithm.
                       
# criterion: entropy or gini
The function to measure the quality of a split. 
Supported criteria are “gini” for the Gini impurity and “entropy” for the information gain.

# max_depth : int or None, optional (default=None)
The maximum depth of the tree. 
If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split sample

# random_state: 난수값

# min_samples_split: 분할 되기 위해 노드가 가져야 하는 최소 샘플 수 
# min_samples_leaf: 리프 노드가 가지고 있어야 할 최소 샘플 수
# max_leaf_nodes: 리프 노드의 최대 수
# max_features: 노드에서 분할에 사용할 특성의 최대 수 

# max_features : int, float, string or None, optional (default=”auto”)
The number of features to consider when looking for the best split:

If int, then consider max_features features at each split.
If float, then max_features is a fraction and int(max_features * n_features) features are considered at each split.
If “auto”, then max_features=sqrt(n_features).
If “sqrt”, then max_features=sqrt(n_features) (same as “auto”).
If “log2”, then max_features=log2(n_features).
If None, then max_features=n_features.

"""
clf = tree.DecisionTreeClassifier('entropy', random_state=0, max_depth=16)

clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=16,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
test_y.value_counts()
# Out:
# 5    136
# 6    128
# 7     40
# 4     11
# 8      3
# 3      2
# Name: quality, dtype: int64

# %%
dot_data = tree.export_graphviz(clf, out_file=None, max_depth=2, feature_names=list(X.columns.values), filled=True, rounded=True)
graphviz.Source(dot_data)

# %%
clf.score(train_X, train_y)
# Out:
# 0.9906176700547302

# %%
clf.score(test_X, test_y)
# Out:
# 0.6125

# %%
clf.tree_.max_depth
# Out:
# 19

# %%
clf.tree_.n_leaves
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-a3d60d33f0a6> in <module>
# ----> 1 clf.tree_.n_leaves
#
# AttributeError: 'sklearn.tree._tree.Tree' object has no attribute 'n_leaves'

# %%
list(zip(X.columns, clf.feature_importances_))
# feature_importances_ 도 coef와 비슷한 느낌.. 해당 feature가 얼마나 영향을 끼치는가
# Out:
# [('fixed acidity', 0.07391906181608769),
#  ('volatile acidity', 0.11629849893284064),
#  ('citric acid', 0.05788886494735533),
#  ('residual sugar', 0.0784970064988638),
#  ('chlorides', 0.05662613198027193),
#  ('free sulfur dioxide', 0.04452005755686164),
#  ('total sulfur dioxide', 0.09170644678797549),
#  ('density', 0.04698259297918923),
#  ('pH', 0.10408914337632276),
#  ('sulphates', 0.11690231085845651),
#  ('alcohol', 0.21256988426577506)]

# %%
clf.classes_
# Out:
# array([3, 4, 5, 6, 7, 8], dtype=int64)

# %%
clf.max_features_
# Out:
# 11

# %%
clf.n_classes_
# Out:
# 6

# %%
clf.n_features_
# Out:
# 11

# %%
clf.tree_.max_depth
# Out:
# 2

# %%
import sklearn
sklearn.__version__
# Out:
# '0.20.3'

# %% [markdown]
# # 실습1. white wine에 대해서 Quality 예측

# %%
new_white=wine_white.copy()

# %%
X=new_white.drop('quality', axis=1)
y=new_white['quality']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y= train_test_split(X, y, stratify=y, random_state=42, test_size=.2, )

# %%
from sklearn import tree
clf= tree.DecisionTreeClassifier('gini', random_state=3)
clf.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=3,
#             splitter='best')

# %%
test_y.value_counts()
# Out:
# 6    440
# 5    291
# 7    176
# 8     35
# 4     33
# 3      4
# 9      1
# Name: quality, dtype: int64

# %%
dot_data=tree.export_graphviz(clf, out_file=None, 
                              max_depth=2, feature_names=list(X.columns.values), 
                              filled=True)
graphviz.Source(dot_data)

# %% [markdown]
# # 실습2. 전체 와인셋(red+ white)에 대해 quality 예측

# %%
new_red.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality class
# 0      9.4        5   Red
# 1      9.8        5   Red

# %%
new_white.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality  class
# 0      8.8        6  White
# 1      9.5        6  White

# %%
new_red['class']=0

# %%
new_white['class']=1

# %%
wineSet=new_red.append(new_white)

# %%
wineSet.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality  class
# 0      9.4        5      0
# 1      9.8        5      0

# %%
wineSet.tail(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  class
# 4896     12.8        7      1
# 4897     11.8        6      1

# %%
X=wineSet.drop('quality', axis=1)
y=wineSet['quality']

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainy, testy=train_test_split(X, y, stratify=y, test_size=.2, random_state=42)

# %%
trainX.head(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3161            6.1              0.17         0.42            15.1      0.033
# 2566            6.9              0.21         0.24             1.8      0.021
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3161                 28.0                 124.0  0.99684  2.87       0.47
# 2566                 17.0                  80.0  0.98992  3.15       0.46
#
#       alcohol  class
# 3161      9.5      1
# 2566     12.3      1

# %%
from sklearn import tree
clf1=tree.DecisionTreeClassifier('entropy', random_state=0)
clf2=tree.DecisionTreeClassifier('entropy', random_state=0, max_features=10)
clf3=tree.DecisionTreeClassifier('entropy', random_state=0, max_features=8)
clf4=tree.DecisionTreeClassifier('entropy', random_state=0, max_features=5)
clf5=tree.DecisionTreeClassifier('entropy', random_state=0, max_features=3)
clf.fit(trainX, trainy)
clf1.fit(trainX, trainy)
clf2.fit(trainX, trainy)
clf3.fit(trainX, trainy)
clf4.fit(trainX, trainy)
clf5.fit(trainX, trainy)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=3, max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=0, splitter='best')

# %%
graphviz.view
# Out:
# <function graphviz.backend.view(filepath)>

# %%
dot_data=tree.export_graphviz(clf, out_file=None, 
                              max_depth=2, feature_names=list(X.columns.values), 
                              filled=True, rounded=True)
graphviz.Source(dot_data)

# %%
print(clf.tree_.max_depth)
print(clf1.tree_.max_depth)
print(clf2.tree_.max_depth)
print(clf3.tree_.max_depth)
print(clf4.tree_.max_depth)
print(clf5.tree_.max_depth)
# (보콩) max features 가 작아질 수록 깊이가 깊어진다!
# Out:
# 10
# 25
# 24
# 26
# 27
# 25

# %%
clf.score(trainX, trainy)
# Out:
# 0.7633249951895325

# %%
clf.score(testX, testy)
# Out:
# 0.56

# %% [markdown]
# # 실습3. 전체 와인셋(red+ white)에 대해 depth가(2부터 20까지 중에 최적 depth 찾기)

# %%
from sklearn.model_selection import train_test_split
depth=list(range(2,20))
trainX, testX, trainy, testy=train_test_split(X, y, stratify=y, test_size=.2, random_state=42)

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1

# %% [markdown]
# # version 별 명령어

# %%
import sklearn
sklearn.__version__
# Out:
# '0.20.3'

# %%
# clf.get_depth
clf.tree_.max_depth
# Out:
# 2
