# %%
# !pip3 uninstall https://github.com/JonathanRaiman/glove/archive/master.zip
# Out:
# ERROR: You must give at least one requirement to uninstall (see "pip help uninstall")

# %%
import glove
# Out:
# ---------------------------------------------------------------------------
# DistutilsPlatformError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     214             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
# --> 215                                    inplace=build_inplace, language_level=language_level)
#     216         mod = imp.load_dynamic(name, so_path)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     190                                   inplace=inplace,
# --> 191                                   reload_support=pyxargs.reload_support)
#     192     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#
# ...

# %%
import numpy as np
import os
import pickle
import time

SENTENCE_LENGTH_MAX = 32
EMBEDDING_DIM = 50

import nltk
nltk.download('punkt')
sentence_splitter = nltk.data.load('tokenizers/punkt/englich.pickle')
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebandkWordTokenizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-4-478eef7e9b96> in <module>
#       9 import nltk
#      10 nltk.download('punkt')
# ---> 11 sentence_splitter = nltk.data.load('tokenizers/punkt/englich.pickle')
#      12 from nltk.tokenize import TreebankWordTokenizer
#      13 tokenizer = TreebandkWordTokenizer()
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in _open(resource_url)
#     991
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-4c1f693c3abc> in <module>
# ----> 1 import glove_python
#
# ModuleNotFoundError: No module named 'glove_python'
